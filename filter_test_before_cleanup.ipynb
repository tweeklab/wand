    (198, 172, 253),
    (150, 97, 253),
    (201, 176, 254),
    (145, 97, 254),
]


# raw_data = raw_data_circle
raw_data = raw_data_triangle
# raw_data = raw_data_silencio
# raw_data = raw_data_test
print(len(raw_data))
# Out:
# 100

# %%
a = np.array(raw_data)
raw_data_grouped = [
    i.tolist() for i in np.split(a[:, :], np.unique(a[:, 2], return_index=True)[1][1:])
]
# raw_data_grouped.reverse()
raw_data_grouped
# Out:
# [[[189, 216, 186]],
#  [[171, 297, 187], [189, 216, 187]],
#  [[171, 298, 188]],
#  [[170, 300, 189], [189, 215, 189]],
#  [[171, 301, 190], [190, 215, 190]],
#  [[173, 298, 191], [190, 214, 191]],
#  [[177, 289, 192], [191, 212, 192]],
#  [[184, 264, 193], [192, 207, 193]],
#  [[191, 205, 194]],
#  [[196, 147, 195]],
#  [[188, 103, 196], [202, 198, 196]],
#  [[180, 85, 197], [199, 192, 197]],
#  [[180, 78, 198], [199, 190, 198]],
#  [[177, 75, 199], [200, 190, 199]],
#  [[173, 79, 200], [199, 189, 200]],
#  [[165, 82, 201], [199, 189, 201]],
#  [[145, 95, 202]],
#  [[79, 188, 203], [188, 194, 203]],
#  [[54, 197, 204], [180, 190, 204]],
#  [[45, 203, 205], [182, 194, 205]],
#  [[47, 213, 206], [177, 191, 206]],
#  [[50, 216, 207], [177, 192, 207]],
#  [[54, 217, 208], [178, 193, 208]],
#  [[59, 220, 209], [179, 193, 209]],
#  [[69, 222, 210], [181, 193, 210]],
#  [[87, 222, 211], [185, 193, 211]],
#  [[126, 225, 212], [194, 200, 212]],
#  [[173, 227, 213]],
#  [[232, 229, 214]],
#  [[266, 226, 215]],
#  [[282, 227, 216]],
#  [[289, 228, 217]],
#  [[292, 227, 218]],
#  [[292, 228, 219]],
#  [[292, 229, 220]],
#  [[292, 230, 221]],
#  [[290, 232, 222]],
#  [[288, 234, 223]],
#  [[287, 235, 224]],
#  [[284, 237, 225]],
#  [[281, 238, 226]],
#  [[280, 238, 227]],
#  [[279, 239, 228]],
#  [[278, 240, 229]],
#  [[278, 239, 230]],
#  [[277, 238, 231]],
#  [[276, 237, 232]],
#  [[274, 236, 233]],
#  [[273, 235, 234]],
#  [[272, 234, 235]],
#  [[271, 234, 236]],
#  [[269, 233, 237]],
#  [[269, 231, 238]],
#  [[269, 230, 239]],
#  [[269, 230, 240]],
#  [[268, 229, 241]],
#  [[267, 227, 242]],
#  [[267, 227, 243]],
#  [[267, 227, 244]],
#  [[267, 226, 245]],
#  [[266, 227, 246]],
#  [[266, 227, 247]],
#  [[265, 227, 248]],
#  [[265, 228, 249]],
#  [[264, 229, 250]],
#  [[264, 229, 251], [203, 187, 251]],
#  [[265, 230, 252]],
#  [[265, 231, 253]],
#  [[265, 231, 254]],
#  [[266, 232, 255]],
#  [[265, 233, 256]],
#  [[264, 233, 257], [212, 192, 257]],
#  [[264, 233, 258], [211, 192, 258]],
#  [[263, 232, 259], [211, 192, 259]]]

# %%
def displacement1(v0, v1):
    angle = np.arctan2(np.linalg.det([v0, v1]), np.dot(v0, v1))
    raw_disp = np.degrees(angle)
    if raw_disp < 0:
        disp = -180 - raw_disp
    else:
        disp = 180 - raw_disp
    return disp


def displacement2(v0, v1):
    angle = np.arctan2(np.linalg.det([v0, v1]), np.dot(v0, v1))
    disp = 180 - np.abs(np.degrees(angle))
    return disp

# %%
min_frame = raw_data_grouped[0][0][2]
filtered_frames = []
frame_q = collections.deque(maxlen=5)
x = []
y = []

heat_bins = 32

start = time()

flat_x = np.array([pt[0] for frame in raw_data_grouped for pt in frame]) - 200
flat_y = np.array([pt[1] for frame in raw_data_grouped for pt in frame]) - 200
H, xedges, yedges = np.histogram2d(
    flat_y, flat_x, bins=heat_bins, range=[(-200, 200), (-200, 200)]
)
q = np.quantile(H[H != 0], [0.25, 0.75])
iqr = q[1] - q[0]

def center(xarg, yarg):
    x = xedges[xarg] + (400 / 64) - 1
    y = yedges[yarg] + (400 / 64) - 1
    return (x, y)

outlier_filter = (H < (q[0] - iqr)) | (H > (q[1] + iqr))
# argware gives us row,column so it's really y,x!
outlier_centers = {
    (np.negative(i[1] - (heat_bins / 2)), i[0] - (heat_bins / 2)): center(
        i[1], i[0]
    )
    for i in np.argwhere(outlier_filter)
}
print(outlier_centers)

def append_filtered_frame(f):
    try:
        print(f"frame: {f}")
        binned_x = f[0][0] // heat_bins
        if binned_x < 0:
            binned_x += 1
        binned_y = f[0][1] // heat_bins
        if binned_y < 0:
            binned_y += 1
        binned_coord = (binned_x,binned_y)
        print(f"binned: {binned_coord}")
        new_coords = outlier_centers[binned_coord]
        print("Filtered!")
        filtered_frames.append((new_coords, f[1]))
    except KeyError:
        filtered_frames.append(f)


for frame in raw_data_grouped:
    adjusted_frame = [
        [(pt[0] - 200, (400 - pt[1]) - 200), pt[2] - min_frame] for pt in frame
    ]
    frame_q.append(adjusted_frame)
    if len(frame_q) < 3:
        # Don't do anything until we have enough points to vote
        continue

    if len(frame_q[0]) == 1:
        # If the frame we are processing only has one hit
        # pass it through assuming it's the wand
        # There is safely only one point here so we can just index it
        # directly
        append_filtered_frame(frame_q[0][0])
        continue

    # Choose the point that results in the lowest angular displacement
    # from the previous point
    # Right now we can't tolerate starting with a frame that has multiple
    # blob hits.  Skip until we get something that is not ambiguous.
    if len(filtered_frames) == 0 and len(frame_q[0]) > 1:
        print("Skip ambiguous start frame")
        continue

    # The grid is made up the of the array indices for each frame so we can
    # easily locate the points in the queue that we need later on.
    # This will always reference filtered_framts[-1] as the previous frame
    # to create the first angle...
    grid = [
        x
        for x in itertools.product(
            [i for i in range(len(frame_q[0]))],
            [i for i in range(len(frame_q[1]))],
            [i for i in range(len(frame_q[2]))],
        )
    ]
    min_grid_idx = None
    min_value = None
    ref_frame = filtered_frames[-1]
    for grid_idx, candidate in enumerate(grid):
        all_disp = []
        for i in range(len(candidate) - 1):
            if i == 0:
                v1 = np.array(ref_frame[0]) - np.array(frame_q[i][candidate[i]][0])  # type: ignore
            else:
                v1 = np.array(frame_q[i - 1][candidate[i - 1]][0]) - np.array(frame_q[i][candidate[i]][0])  # type: ignore
            v0 = np.array(frame_q[i + 1][candidate[i + 1]][0]) - np.array(frame_q[i][candidate[i]][0])  # type: ignore
            all_disp.append(displacement2(v0, v1) * np.linalg.norm(v1))

        total_disp = sum(all_disp)
        if not min_value or total_disp < min_value:
            min_value = total_disp
            min_grid_idx = grid_idx

    if min_grid_idx is None:
        raise Exception("Derp!")
    else:
        new_point = frame_q[0][grid[min_grid_idx][0]]
        append_filtered_frame(new_point)
print(f"{time()-start}")


for frame in filtered_frames:
    x.append(frame[0][0])
    y.append(frame[0][1])
vectors = pd.DataFrame(
    {
        "x": x,
        "y": y,
    }
)
vectors
# Out:
# {(2.0, -1.0): (-19.75, -7.25), (-5.0, 2.0): (67.75, 30.25)}
# frame: [(-11, -16), 0]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 65
#      58     continue
#      60 if len(frame_q[0]) == 1:
#      61     # If the frame we are processing only has one hit
#      62     # pass it through assuming it's the wand
#      63     # There is safely only one point here so we can just index it
#      64     # directly
# ---> 65     append_filtered_frame(frame_q[0][0])
#      66     continue
#      68 # Choose the point that results in the lowest angular displacement
#      69 # from the previous point
#      70 # Right now we can't tolerate starting with a frame that has multiple
#      71 # blob hits.  Skip until we get something that is not ambiguous.
#
# Cell In[81], line 43, in append_filtered_frame(f)
#      41 if binned_y < 0:
#      42     binned_y += 1
# ---> 43 print(f"binned: {binned_coord}")
#      44 new_coords = outlier_centers[binned_coord]
#      45 print("Filtered!")
#
# NameError: name 'binned_coord' is not defined

# %%
sns.set(style="darkgrid")

fig = plt.figure(figsize=(10, 6), dpi=100)
ax_fixed = fig.add_subplot(131)
ax_orig = fig.add_subplot(132)
ax_hist = fig.add_subplot(133)

ax_orig.set_xlabel("X")
ax_orig.set_ylabel("Y")
ax_orig.set(ylim=(-200, 200), xlim=(-200, 200))
ax_orig.plot(vectors.x, vectors.y, color="green", marker=".", linewidth=1)

ax_fixed.set_xlabel("X")
ax_fixed.set_ylabel("Y")
ax_fixed.set(ylim=(-200, 200), xlim=(-200, 200))
ax_fixed.plot(
    [pt[0] - 200 for frame in raw_data_grouped for pt in frame],
    [(400 - pt[1]) - 200 for frame in raw_data_grouped for pt in frame],
    color="green",
    marker=".",
    linewidth=1,
)

X, Y = np.meshgrid(xedges, yedges)
ax_hist.set(ylim=(-200,200), xlim=(-200,200))
ax_hist.pcolormesh(X, Y, H)
ax_hist.scatter(
    [i[0] for i in outlier_centers.values()],
    [i[1] for i in outlier_centers.values()],
    color="red",
    marker="+",
    linewidth=1,
)
ax_hist.invert_yaxis()

# %% [raw]
# min_frame = raw_data_grouped[0][0][2]
# filtered_frames = []
# frame_q = collections.deque(maxlen=3)
# x = []
# y = []
#
# frames = []
# mags = []
# angles = []
# coord_complex = []
# exclude_flag = []
#
# c = Counter()
# arr = np.array([complex(pt[0] - 200, (400 - pt[1]) - 200) for frame in raw_data_grouped for pt in frame])
# for point in arr:
#     diffs = np.abs(arr - point)
#     smallest = heapq.nsmallest(10, diffs.tolist())
#     for s in smallest:
#         c[arr[np.argwhere(diffs == s)[0][0]]] += 1
# common = np.array([x[0] for x in filter(lambda x: x[1] > 10, c.most_common())])
#
# for frame in raw_data_grouped:
#     complex_frame = [(complex(pt[0] - 200, (400 - pt[1]) - 200),pt[2]-min_frame) for pt in frame]
#     frame_q.append(complex_frame)
#     if len(frame_q) < 3:
#         # Don't do anything until we have enough points to vote
#         continue
#
#     working_frame = frame_q[1]
#
#     if len(working_frame) == 1:
#         # If the frame we are processing only has one hit
#         # pass it through assuming it's the wand.
#         filtered_frames.extend(working_frame)
#         continue
#
#     # If there's more than one point we have some work to do.
#     #######
#     # Angular displacement
#     # Choose the point that results in the lowest angular displacement
#     # from the previous point
#     try:
#         prev_frame = filtered_frames[-1]
#     except IndexError:
#         prev_frame = frame_q[0]
#         assert len(prev_frame) == 1
#         prev_frame = prev_frame[0]
#
#     prev_frame_coords = prev_frame[0]
#     prev_angles = []
#     for wf in working_frame:
#         wf_coords = wf[0]
#         if np.any(np.abs(common-wf_coords) < 5):
#             continue
#         angle = np.angle(wf_coords - prev_frame_coords, deg=True)
#         dist = np.absolute(wf_coords - prev_frame_coords)
#         prev_angles.append(angle)
#     if prev_angles:
#         selected_idx = np.argmin(prev_angles)
#         filtered_frames.append(working_frame[selected_idx])
#
# for frame in filtered_frames:
#     x.append(np.real(frame[0]))
#     y.append(np.imag(frame[0]))
# vectors = pd.DataFrame(
#     {
#         "x": x,
#         "y": y,
#     }
# )

# %% [raw]
# min_frame = raw_data_grouped[0][0][2]
# filtered_frames = []
# frame_q = collections.deque(maxlen=3)
# x = []
# y = []
# frames = []
# mags = []
# angles = []
# coord_complex = []
# exclude_flag = []
#
# c = Counter()
# arr = np.array([complex(pt[0] - 200, (400 - pt[1]) - 200) for frame in raw_data_grouped for pt in frame])
# for point in arr:
#     diffs = np.abs(arr - point)
#     smallest = heapq.nsmallest(10, diffs.tolist())
#     for s in smallest:
#         c[arr[np.argwhere(diffs == s)[0][0]]] += 1
# common = np.array([x[0] for x in filter(lambda x: x[1] > 20, c.most_common())])
#
# for frame in raw_data_grouped:
#     complex_frame = [(complex(pt[0] - 200, (400 - pt[1]) - 200),pt[2]-min_frame) for pt in frame]
#     frame_q.append(complex_frame)
#     if len(frame_q) < 3:
#         # Don't do anything until we have enough points to vote
#         continue
#
#     working_frame = frame_q[1]
#
#     if len(working_frame) == 1:
#         # If the frame we are processing only has one hit
#         # pass it through assuming it's the wand.
#         filtered_frames.extend(working_frame)
#         continue
#
#     # If there's more than one point we have some work to do.
#
#     ###########
#     # KMeans - try to remove common mode noise when there is a tie between
#     # center points as indicated by the trained model labels
#     # from sklearn.cluster import KMeans
#     # flat_points = [(np.real(j[0]), np.imag(j[0])) for i in frame_q for j in i]
#     # group_count = max([len(i) for i in frame_q])
#     # model = KMeans(group_count, n_init='auto', random_state=3).fit(flat_points)
#     # # Test to ensure we can use labels_ in place of re-running prediction
#     # # assert np.all(model.predict(flat_points) == model.labels_)
#     # class_counts = np.unique(model.labels_, return_counts=True) # type: ignore
#     # if np.all(class_counts[1] == class_counts[1][0]):
#     #     continue
#
#     #######
#     # Angular displacement
#     # Choose the point that results in the lowest angular displacement
#     # from the previous point
#     try:
#         prev_frame = filtered_frames[-1]
#     except IndexError:
#         prev_frame = frame_q[0]
#         assert len(prev_frame) == 1
#         prev_frame = prev_frame[0]
#
#     prev_frame_coords = prev_frame[0]
#     prev_angles = []
#     for wf in working_frame:
#         wf_coords = wf[0]
#         if np.any(np.abs(common-wf_coords) < 5):
#             print("Common")
#             continue
#         angle = np.angle(wf_coords - prev_frame_coords, deg=True)
#         dist = np.absolute(wf_coords - prev_frame_coords)
#         prev_angles.append(angle)
#     if prev_angles:
#         selected_idx = np.argmin(prev_angles)
#         filtered_frames.append(working_frame[selected_idx])
#
#
#     # ###########
#     # # KMeans - try to remove common mode noise when there is a tie between
#     # center points as indicated by the trained model labels
#     # from sklearn.cluster import KMeans
#     # flat_points = [(np.real(j[0]), np.imag(j[0])) for i in frame_q for j in i]
#     # group_count = max([len(i) for i in frame_q])
#     # model = KMeans(group_count, n_init='auto', random_state=3).fit(flat_points)
#     # class_counts = np.unique(model.predict(flat_points), return_counts=True)
#     # if np.all(class_counts[1] == class_counts[1][0]):
#     #     continue
#
#     # # Find the most unique point.  Find the center with the least number
#     # # of predicted points, and select the point in the frame closest to
#     # # that center
#     # selected_class = class_counts[1].argmin()
#     # selected_center = model.cluster_centers_[selected_class]
#     # # Get rid of the frame number from each point
#     # wf = np.delete(np.array(working_frame), 1, 1)
#     # selected_real_point = wf[np.abs(wf - complex(*selected_center)).argmin()]
#     # filtered_frames.append((selected_real_point, working_frame[1]))
#
#
# #     mag_short = np.absolute(point_q[-1] - point_q[-2])
# #     angle_short = np.angle(point_q[-1] - point_q[-2], deg=True)
#
# #     mag_long = np.absolute(point_q[-1] - point_q[-3])
# #     angle_long = np.angle(point_q[-1] - point_q[-3], deg=True)
#
# #     if (angle_short - angle_long) > 30:
# #         exclude_flag.append(True)
# #     else:
# #         exclude_flag.append(False)
#
# #     x.append(np.real(point_q[-2]))
# #     y.append(np.imag(point_q[-2]))
# #     coord_complex.append(f"{point_q[-2]}")
# #     mags.append(mag_short)
# #     angles.append(mag_long)
# #     frames.append(pt[2] - min_frame)
# # vectors = pd.DataFrame(
# #     {
# #         "x": x,
# #         "y": y,
# #         "magnitude": mags,
# #         "angle": angles,
# #         "frame": frames,
# #         "complex": coord_complex,
# #         "exclude": exclude_flag,
# #     }
# # )
#
# for frame in filtered_frames:
#     x.append(np.real(frame[0]))
#     y.append(np.imag(frame[0]))
# vectors = pd.DataFrame(
#     {
#         "x": x,
#         "y": y,
#     }
# )

# %% [raw]
# filtered = []
# min_frame = raw_data[0][2]
# for pt in raw_data:
#     filtered.append((pt[0], pt[1], pt[2] - min_frame))
# arr = np.array(filtered)
# split_arr = np.squeeze(np.hsplit(arr, 3))
# points_df = pd.DataFrame({"x": split_arr[0], "y": split_arr[1], "z": split_arr[2]})
#
# # def dist(x, y, z):
# #     start = np.array((x[0], y[0]))
# #     end = np.array((x[1], y[1]))
# #     return np.linalg.norm(end - start)
#
# # def centeroidnp(x, y):
# #     length = x.shape[0]
# #     sum_x = np.sum(x)
# #     sum_y = np.sum(y)
# #     return sum_x/length, sum_y/length
#
# # # points_df['dist'] = rolling_apply(dist, 10, points_df.x.values, points_df.y.values, points_df.z.values)
# # # points_df[['cx', 'cy']] = rolling_apply(fit, 9, points_df.x.values, points_df.y.values)
# # # points_df_sort = points_df.sort_values('z', ascending=False)
# # points_df = points_df.sort_values(['x', 'y', 'z']).reset_index(drop=True)
# # points_df[['cx', 'cy']] = rolling_apply(centeroidnp, 9, points_df.x.values, points_df.y.values)
# # points_df['dist'] = rolling_apply(dist, 2, points_df.x.values, points_df.y.values, points_df.z.values)
# # points_df = points_df[points_df.dist > 10].sort_values('z')

# %% [raw]
# print(time())
# c = Counter()
# arr = np.array([x for x in zip(points_df.x, points_df.y, points_df.z)])
# for point in arr:
#     diffs = np.abs(arr - point)
#     smallest = [x for x in filter(lambda x: x[2] < 15, heapq.nsmallest(10, diffs.tolist()))]
#     for s in smallest:
#         c[tuple(arr[np.argwhere(diffs == s)[0][0]])] += 1
# common = np.array([x[0] for x in filter(lambda x: x[1] > 50, c.most_common())])
# common
# # split_arr = np.squeeze(np.hsplit(common, 3))
# # mask_df = pd.DataFrame({"x": split_arr[0], "y": split_arr[1], "z": split_arr[2]})
# # print(time())
# # mask_df

# %% [raw]
# %matplotlib widget
#
# sns.set(style = "darkgrid")
#
# fig = plt.figure(figsize=(8,5))
# ax_orig = fig.add_subplot(121, projection = '3d')
# ax_mean = fig.add_subplot(122, projection = '3d')
#
# ax_orig.set_xlabel("X")
# ax_orig.set_ylabel("Y")
# ax_orig.set_zlabel("Frame")
# ax_orig.set(ylim=(0,400), xlim=(0,400), zlim=(0,100))
# ax_orig.invert_yaxis()
# # orig_scatter = ax_orig.scatter(points_df.x, points_df.y, points_df.z, c=points_df.dist)
# orig_scatter = ax_orig.scatter(points_df.x, points_df.y, points_df.z)
# # ax_orig.legend(*orig_scatter.legend_elements(), loc="lower left", title="Distance")
#
# ax_mean.set_xlabel("X")
# ax_mean.set_ylabel("Y")
# ax_mean.set_zlabel("Frame")
# ax_mean.set(ylim=(0,400), xlim=(0,400), zlim=(0,100))
# ax_mean.invert_yaxis()
# # mean_scatter = ax_mean.scatter(points_df.cx, points_df.cy, points_df.z)
# mean_scatter = ax_mean.scatter(mask_df.x, mask_df.y, mask_df.z)

# %%
# quant = 1
# arr = np.array(flat_data)
# split_arr = np.squeeze(np.hsplit(arr, 3))
# # raw_df = pd.DataFrame({'x': split_arr[0], 'y': split_arr[1], 'value': split_arr[2]})
# raw_df = pd.DataFrame({'x': split_arr[0], 'y': split_arr[1]})
# raw_df.x = raw_df.x.apply(lambda x: x//quant)
# raw_df.y = raw_df.y.apply(lambda x: x//quant)
# raw_df

# %%
# counts = raw_df.value_counts().reset_index()
# counts.rename({0: 'count'}, axis=1, inplace=True)
# # filt_counts = counts[(counts['value'] < 150) & (counts['count'] < 2)]
# filt_counts = counts[(counts['count'] < 2)]
# # filt_counts = counts
# # ax = sn.scatterplot(filt_counts, x='x', y='y', size='count', hue='value')
# ax = sn.scatterplot(filt_counts, x='x', y='y', hue='count')
# ax.set(ylim=(0,400//quant), xlim=(0,400//quant))
# ax.invert_yaxis()
